# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.1.3'

# %%
from matplotlib import pyplot as plt
#ploting our canvas
plt.plot([1,2,3],[4,5,1])
#display the graph
plt.show()

# %%
from matplotlib import pyplot as plt
x=[5,2,7]
y=[1,10,4]
plt.plot(x,y)
plt.title('Line graph')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %%
plt.plot([1,2,3,4,5])
plt.ylabel("y axis")
plt.xlabel('x axis')
plt.show()

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25])
plt.ylabel("y axis")
plt.xlabel('x axis')
plt.show()

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25],'ro')
plt.axis([0,6,0,20])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-12c316a18aef> in <module>
# ----> 1 plt.plot([1,2,3,4,5],[1,4,9,16,25],'ro')
#       2 plt.axis([0,6,0,20])
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
from matplotlib import pyplot as plt
plt.plot([1,2,3,4,5],[1,4,9,16,25],'ro')
plt.axis([0,6,0,20])
plt.show()
